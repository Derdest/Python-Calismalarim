# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
analys=pd.read_csv("veri analizi/deliverytime.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 analys=pd.read_csv("veri analizi/deliverytime.csv")
#
# NameError: name 'pd' is not defined

# %%
analys

# %%
analys.head()
# Out:
#      ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0  4607                   37                      4.9        Snack
# 1  B379                   34                      4.5        Snack
# 2  5D6D                   23                      4.4       Drinks
# 3  7A6A                   38                      4.7       Buffet
# 4  70A2                   32                      4.6        Snack
#
#   Type_of_vehicle  Time_taken(min)
# 0     motorcycle                24
# 1        scooter                33
# 2     motorcycle                26
# 3     motorcycle                21
# 4        scooter                30

# %%
len(analys.columns)
# Out:
# 6

# %%
len(analys.index)
# Out:
# 45593

# %%
analys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       45593 non-null  object
#  1   Delivery_person_Age      45593 non-null  int64
#  2   Delivery_person_Ratings  45593 non-null  float64
#  3   Type_of_order            45593 non-null  object
#  4   Type_of_vehicle          45593 non-null  object
#  5   Time_taken(min)          45593 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
analys.shape
# Out:
# (45593, 6)

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)
# 0         motorcycle                24
# ...

# %%
id_loc=analys["Delivery_person_ID"].apply(lambda x:x[0:4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Delivery_person_ID'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
id_loc
# Out:
# 0        INDO
# 1        BANG
# 2        BANG
# 3        COIM
# 4        CHEN
#          ...
# 45588    JAPR
# 45589    AGRR
# 45590    CHEN
# 45591    COIM
# 45592    RANC
# Name: Delivery_person_ID, Length: 45593, dtype: object

# %%
rest=[]
for i in list(zip(analys["Restaurant_latitude"],analys["Restaurant_longitude"])):
    rest.append(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Restaurant_latitude'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(rest)
# Out:
# []

# %%
delivery=[]

# %%
analys.head(n=11)
# Out:
#       ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0   4607                   37                      4.9        Snack
# 1   B379                   34                      4.5        Snack
# 2   5D6D                   23                      4.4       Drinks
# 3   7A6A                   38                      4.7       Buffet
# 4   70A2                   32                      4.6        Snack
# 5   9BB4                   22                      4.8       Buffet
# 6   95B4                   33                      4.7         Meal
# 7   9EB2                   35                      4.6         Meal
# 8   1102                   22                      4.8       Buffet
# 9   CDCD                   36                      4.2        Snack
# 10  D987                   21                      4.7         Meal
#
#    Type_of_vehicle  Time_taken(min)
# 0      motorcycle                24
# 1         scooter                33
# 2      motorcycle                26
# ...

# %%
analys.drop(["Delivery_person_ID","Restaurant_latitude","Restaurant_longitude","Delivery_location_latitude","Delivery_location_longitude"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 analys.drop(["Delivery_person_ID","Restaurant_latitude","Restaurant_longitude","Delivery_location_latitude","Delivery_location_longitude"],axis=1,inplace=True)
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\Program Files\Anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)
# 0         motorcycle                24
# ...

# %%
analys.head(n=1)
# Out:
#      ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0  4607                   37                      4.9        Snack
#
#   Type_of_vehicle  Time_taken(min)
# 0     motorcycle                24

# %%
analys.groupby("Time_taken(min)").mean()[["Delivery_person_Ratings"]].head()
# Out:
# C:\Users\ihaka\AppData\Local\Temp\ipykernel_5356\1781456048.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   analys.groupby("Time_taken(min)").mean()[["Delivery_person_Ratings"]].head()
#                  Delivery_person_Ratings
# Time_taken(min)
# 10                              4.751200
# 11                              4.750066
# 12                              4.746783
# 13                              4.752235
# 14                              4.745737

# %%
analys["Delivery_person_Age"].value_counts()
# Out:
# 29    4045
# 35    2262
# 36    2260
# 37    2227
# 30    2226
# 38    2219
# 24    2210
# 32    2202
# 22    2196
# 33    2187
# 28    2179
# 25    2174
# 34    2166
# 26    2159
# 21    2153
# 27    2150
# 39    2144
# 20    2136
# 31    2120
# 23    2087
# 50      53
# 15      38
# Name: Delivery_person_Age, dtype: int64

# %%
analys.to_csv("veri analizi deneme/deliverytime.csv")

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)
# 0         motorcycle                24
# ...

# %%
analys2.to_csv("deliverytime2.csv")

# %%
analys2=analys.drop(["ID"],axis=1)

# %%
analys2

# %%
analys2.to_csv("deliverytime.csv")

# %%
analys2.to_csv("deliverytime.csv",index=False)

# %%
analys2
# Out:
#        Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0                       37                      4.9        Snack
# 1                       34                      4.5        Snack
# 2                       23                      4.4       Drinks
# 3                       38                      4.7       Buffet
# 4                       32                      4.6        Snack
# ...                    ...                      ...           ...
# 45588                   30                      4.8         Meal
# 45589                   21                      4.6       Buffet
# 45590                   30                      4.9       Drinks
# 45591                   20                      4.7        Snack
# 45592                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)
# 0         motorcycle                24
# 1            scooter                33
# 2         motorcycle                26
# ...

# %%
analys2.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Type_of_order Type_of_vehicle  \
# 0                   37                      4.9        Snack      motorcycle
# 1                   34                      4.5        Snack         scooter
# 2                   23                      4.4       Drinks      motorcycle
# 3                   38                      4.7       Buffet      motorcycle
# 4                   32                      4.6        Snack         scooter
#
#    Time_taken(min)
# 0               24
# 1               33
# 2               26
# 3               21
# 4               30

# %%
for i in analys["Delivery_person_Age"].unique():
    print(i)
# Out:
# 37
# 34
# 23
# 38
# 32
# 22
# 33
# 35
# 36
# 21
# 24
# 29
# 25
# 31
# 27
# 26
# 20
# 28
# 39
# 30
# 15
# 50

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)
# 0         motorcycle                24
# ...

# %%
def new_column(Delivery_person_Age):
    if Delivery_person_Age<=20:
        return Delivery_person_Age
    elif 20<Delivery_person_Age<=30:
        return "Teslim edenin yaşı 30 den küçük"
    elif 30<Delivery_person_Age<=40:
        return Delivery_person_Age
    elif 40<Delivery_person_Age<=50:
        return "Teslim edenin yaşı 50 den küçük"
analys["Teslim eden yaşı"]=analys["Delivery_person_Age"].apply(new_column)

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)                 Teslim eden yaşı
# ...

# %%
analys["Type_of_vehicle"].unique()
# Out:
# array(['motorcycle ', 'scooter ', 'electric_scooter ', 'bicycle '],
#       dtype=object)

# %%
def m_letter_counter(Type_of_vehicle):
    list=[]
    list=Type_of_vehicle.split("m")
    return len(list)
analys["m_harfi_sayacı"]=analys["Type_of_vehicle"].apply(m_letter_counter)

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)                 Teslim eden yaşı  \
# ...

# %%
def m_letter2(m_harfi_sayacı):
    a=int(m_harfi_sayacı)
    a-=1
    return a
analys["m_harf_sayacı"]=analys["m_harfi_sayacı"].apply(m_letter2)

# %%
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)                 Teslim eden yaşı  \
# ...

# %%
def m_letter_counter(Type_of_vehicle):
    list=[]
    list=Type_of_vehicle.split("m")
    return len(list)
analys["m_harfi_sayacı"]=analys["Type_of_vehicle"].apply(m_letter_counter)


def m_letter2(m_harfi_sayacı):
    a=int(m_harfi_sayacı)
    a-=1
    return a
analys["m_harf_sayacı"]=analys["m_harfi_sayacı"].apply(m_letter2)
analys.drop(["m_harfi_sayacı"],axis=1,inplace=True)
analys
# Out:
#          ID  Delivery_person_Age  Delivery_person_Ratings Type_of_order  \
# 0      4607                   37                      4.9        Snack
# 1      B379                   34                      4.5        Snack
# 2      5D6D                   23                      4.4       Drinks
# 3      7A6A                   38                      4.7       Buffet
# 4      70A2                   32                      4.6        Snack
# ...     ...                  ...                      ...           ...
# 45588  7C09                   30                      4.8         Meal
# 45589  D641                   21                      4.6       Buffet
# 45590  4F8D                   30                      4.9       Drinks
# 45591  5EEE                   20                      4.7        Snack
# 45592  5FB2                   23                      4.9        Snack
#
#       Type_of_vehicle  Time_taken(min)                 Teslim eden yaşı  \
# ...
