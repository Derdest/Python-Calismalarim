# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,axes=plt.subplots(nrows=2, ncols=2)

# %%
fig,axes=plt.subplots(nrows=2,ncols=2)
plt.tight_layout()  #GÖRÜNÜMÜ DAHA DÜZENLİ YAPMAYA YARAR

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
plt.tight_layout()
#BURADA GRAFİKLER BİR LİSTE HALİNDE OLDUĞU İÇİN FOR DÖNGÜSÜ İLE ÜZERİNDE GEZİNEBİLİRİZ
#LİSTE HALİNDE OLDUĞU İÇİN print İŞLEMİ YAPARAK DA KULLANABİLİRİZ...

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
for ax in axes:
    ax.plot(x,y)
plt.tight_layout()

#BU İŞLEMİ AYRICA ŞÖYLE DE YAPABİLİRDİK...
#fig,axes=plt.subplots(nrows=2,ncols=1)
#axes[0].plot(x,y)
#axes[1].plot(x,y)
#plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
axes[0].plot(x,y)
axes[0].set_title("First Axes")
axes[1].plot(x,y)
axes[1].set_title("Second Axes")
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
for ax in axes:
    ax.plot(x,y)
axes[0].set_title("First Axes")
axes[1].set_title("Second Axes")
plt.tight_layout()

# %%
#ÜSTTEKİ 2 GÖRSELDE AXESLERE BAŞLIK EKLENDİ

# %%
fig=plt.figure(figsize=(4,5))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")
#BURADA figure ekleyip bu figürün boyutunda oalcak şekilde görseli boyutlandırdık...
